# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlalchemy as sql

# %matplotlib inline

# %%
all_songs = pd.read_csv(r'clean_playlist.csv')
all_songs.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  explicit                      id          name  \
# 0           0             0     False  0FE9t6xYkqWXU2ahLh6D8X  Shape of You
# 1           1             1     False  5ZULALImTm80tzUbYQYM9d  Dance Monkey
# 2           2             2      True  7wGoVu4Dady5GV0Sv4UIsx      rockstar
# 3           3             3     False  1xznGGDReH1oQq0xzbwXa3     One Dance
# 4           4             4     False  7BKLCZ1jbUBVqRi2FVlTVw        Closer
#
#    popularity  danceability  energy    key  loudness  ... speechiness  \
# 0          72         0.825   0.652  C#/Db    -3.183  ...      0.0802
# 1          79         0.824   0.588  F#/Gb    -6.400  ...      0.0924
# 2           1         0.577   0.522      F    -6.594  ...      0.0984
# 3           3         0.791   0.619  C#/Db    -5.886  ...      0.0532
# 4          85         0.748   0.524     Ab    -5.599  ...      0.0338
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms_y  \
# ...

# %%
all_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4153 entries, 0 to 4152
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        4153 non-null   int64
#  1   Unnamed: 0.1      4153 non-null   int64
#  2   explicit          4153 non-null   bool
#  3   id                4153 non-null   object
#  4   name              4153 non-null   object
#  5   popularity        4153 non-null   int64
#  6   danceability      4153 non-null   float64
#  7   energy            4153 non-null   float64
#  8   key               4153 non-null   object
#  9   loudness          4153 non-null   float64
#  10  mode              4153 non-null   object
#  11  speechiness       4153 non-null   float64
#  12  acousticness      4153 non-null   float64
#  13  instrumentalness  4153 non-null   float64
#  14  liveness          4153 non-null   float64
#  15  valence           4153 non-null   float64
# ...

# %%
all_songs.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1   popularity  danceability       energy  \
# count  4153.000000   4153.000000  4153.000000   4153.000000  4153.000000
# mean   2076.000000   2076.000000    56.550927      0.643721     0.666766
# std    1199.012163   1199.012163    27.962538      0.151815     0.179685
# min       0.000000      0.000000     0.000000      0.149000     0.054100
# 25%    1038.000000   1038.000000    55.000000      0.544000     0.552000
# 50%    2076.000000   2076.000000    68.000000      0.660000     0.688000
# 75%    3114.000000   3114.000000    74.000000      0.754000     0.801000
# max    4152.000000   4152.000000   100.000000      0.974000     0.995000
#
#           loudness  speechiness  acousticness  instrumentalness     liveness  \
# count  4153.000000  4153.000000   4153.000000       4153.000000  4153.000000
# mean     -6.401435     0.099940      0.198145          0.020169     0.178452
# std       2.726780     0.097237      0.234234          0.100736     0.140017
# ...

# %%
import sqlalchemy as sql
