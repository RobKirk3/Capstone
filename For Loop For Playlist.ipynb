# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
import tekore as tk
# import folium
# import pickle

# import spotipy.oauth2
# from spotipy.oauth2 import SpotifyOAuth
# import spotipy.util as util
# import spotipy

# %store -r api_key
# %matplotlib inline

import base64

# %%
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = 'b039d22df7ae46588961e0c0aac1b82a'
client_secret = 'cbc08f05e5ba4d77bf5edf60ce71d4eb'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

playlist_id = 'spotify:playlist:0nwC4WbX0wGfH1Asj185R6'
results = sp.playlist('spotify:playlist:0nwC4WbX0wGfH1Asj185R6')

# %%
base64.b64encode(client_id.encode('utf-8'))

# %%
#storage cell
# Playlist URI
# spotify:playlist:0nwC4WbX0wGfH1Asj185R6

# audio analysis
# endpoint = 'https://api.spotify.com/v1/audio-analysis/{id}'

# %% [markdown]
# # ====== Token ======

# %%
token = ("BQA7lbz8un08Uqf8CTDCDj5DeN0omrRHFw4wPEqJsfM8FsIn9WHB0udupKe0mRCkJRG5SSgnc5grO48KyVQDEz4Z_7uJ0sdQRBXJFYpgy1gJirfRezlgO6PDnZEEzgELtmdMRxbQikr7LhYzXiJg5tZ7qznS7Ap3BlM")

# %%
headers = {'Authorization':'Bearer '+token}

# %%
headers
# Out:
# {'Authorization': 'Bearer BQA7lbz8un08Uqf8CTDCDj5DeN0omrRHFw4wPEqJsfM8FsIn9WHB0udupKe0mRCkJRG5SSgnc5grO48KyVQDEz4Z_7uJ0sdQRBXJFYpgy1gJirfRezlgO6PDnZEEzgELtmdMRxbQikr7LhYzXiJg5tZ7qznS7Ap3BlM'}

# %%
params = {'id':'6rqhFgbbKwnb9MLmUQDhG6'}

# %% [markdown]
# # able to get audio analysis with 'audio_test'

# %%
audio_test = requests.get("https://api.spotify.com/v1/audio-analysis/6rqhFgbbKwnb9MLmUQDhG6",headers=headers)

# %%
audio_test.json()
# Out:
# {'meta': {'analyzer_version': '4.0.0',
#   'platform': 'Linux',
#   'detailed_status': 'OK',
#   'status_code': 0,
#   'timestamp': 1454195195,
#   'analysis_time': 2.64845,
#   'input_process': 'libvorbisfile L+R 44100->22050'},
#  'track': {'num_samples': 1440183,
#   'duration': 65.31442,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 3.75002,
#   'start_of_fade_out': 65.31442,
#   'loudness': -33.35,
#   'tempo': 119.504,
#   'tempo_confidence': 0.0,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'key': 1,
#   'key_confidence': 0.017,
#   'mode': 1,
#   'mode_confidence': 0.262,
# ...

# %% [markdown]
# # playlist level data

# %%
playlist_test = requests.get("https://api.spotify.com/v1/playlists/0nwC4WbX0wGfH1Asj185R6", headers=headers)5

# %%
playlist_json = playlist_test.json()

# %%
playlist_json['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist_json['tracks']['items']
# Out:
# [{'added_at': '2017-01-21T00:53:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/powgen'},
#    'href': 'https://api.spotify.com/v1/users/powgen',
#    'id': 'powgen',
#    'type': 'user',
#    'uri': 'spotify:user:powgen'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
# ...

# %%
playlist_json
# the 'id' is also the track 'uri'
# Out:
# {'collaborative': False,
#  'description': '3000+ Songs in March 2020 | 4000+ Songs in March 2021',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/0nwC4WbX0wGfH1Asj185R6'},
#  'followers': {'href': None, 'total': 472},
#  'href': 'https://api.spotify.com/v1/playlists/0nwC4WbX0wGfH1Asj185R6',
#  'id': '0nwC4WbX0wGfH1Asj185R6',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b27383e9b06ccd219248b5301264ab67616d0000b2739416ed64daf84936d89e671cab67616d0000b273aa1beea495a0070294c30e31ab67616d0000b273b1c4b76e23414c9f20242268',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b27383e9b06ccd219248b5301264ab67616d0000b2739416ed64daf84936d89e671cab67616d0000b273aa1beea495a0070294c30e31ab67616d0000b273b1c4b76e23414c9f20242268',
#    'width': 300},
#   {'height': 60,
# ...

# %% [markdown]
# # ^^^^^This returns the first 100 tracks from the playlist ^^^^^

# %% [markdown]
# # Let's try the full playlist

# %%
params = {'limit':5000}

# %%
playlist_full = requests.get("https://api.spotify.com/v1/playlists/0nwC4WbX0wGfH1Asj185R6",headers=headers)

# %%
playlist_full_json = playlist_full.json()

# %%
playlist_full_json
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0nwC4WbX0wGfH1Asj185R6/tracks?offset=4100&limit=100',
#  'items': [{'added_at': '2021-04-11T18:45:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/powgen'},
#     'href': 'https://api.spotify.com/v1/users/powgen',
#     'id': 'powgen',
#     'type': 'user',
#     'uri': 'spotify:user:powgen'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3x8FbPjh2Qz55XMdE2Yalj'},
#        'href': 'https://api.spotify.com/v1/artists/3x8FbPjh2Qz55XMdE2Yalj',
#        'id': '3x8FbPjh2Qz55XMdE2Yalj',
#        'name': 'Nick Mulvey',
#        'type': 'artist',
#        'uri': 'spotify:artist:3x8FbPjh2Qz55XMdE2Yalj'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
# ...

# %%
playlist_full_json['tracks']['next']
# Out:
# 'https://api.spotify.com/v1/playlists/0nwC4WbX0wGfH1Asj185R6/tracks?offset=100&limit=100'

# %%
playlist_full_json['tracks']['items']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-3fac4fd21d7d> in <module>
# ----> 1 playlist_full_json['tracks']['items']
#
# KeyError: 'tracks'

# %% [markdown]
# # getting individual 'track' out of 'playlist' mess

# %%
playlist_json['tracks']['items'][0]['track']['id']
# Out:
# '0FE9t6xYkqWXU2ahLh6D8X'

# %%
# getting IDs with previous pull
audio_test = requests.get("https://api.spotify.com/v1/audio-analysis/"+playlist_json['tracks']['items'][0]['track']['id'],headers=headers)

# %%
audio_test.json()

# %%
# build a for loop, iterate over playlist_json, for each iteration, print out track and id, should get list of ids
# start small, inside for loop put it 
# get a list of ids

# %%
# for track in playlist_json
#     do this playlist_json['tracks']['items'][0]['track']['id']
#     put that into a [] as a list

# %%
# this code was copied from stackoverflow to go along with the for loop below, but doesn't work?
resp_dict = json.load(playlist_json)

# %%
song_id_list = []

for x in playlist_full_json['tracks']['items']:
    song_id_list.append(x['track']['id'])

# To see if it worked
for item in song_id_list:
    print(item)
# Out:
# 0FE9t6xYkqWXU2ahLh6D8X
# 5ZULALImTm80tzUbYQYM9d
# 7wGoVu4Dady5GV0Sv4UIsx
# 1xznGGDReH1oQq0xzbwXa3
# 7BKLCZ1jbUBVqRi2FVlTVw
# 0sf12qNH5qcw8qpgymFOqD
# 1A6OTy97kk0mMdm78rHsm8
# 6T8cJz5lAqGer9GUHGyelE
# 34gCuhDGsG4bRPIf9bb02f
# 0TK2YIli7K1leLovkQiNik
# 2TIlqbIneP0ZY1O0EzYLlc
# 2Fxmhks0bxGSBdJ92vM42m
# 5uCax9HTNlzGybIStD3vDh
# 0tgVpDi06FyKpA1z0VMD4v
# 6VRghJeP6I0w1KxkdWFfIh
# 0ofbQMrRDsUaVKq2mGLEAb
# 3hB5DgAiMAQ4DzYbsMq1IT
# 1HNkqx9Ahdgi1Ixy2xkKkL
# 7lQqaqZu0vjxzpdATOIsDt
# 1Y8tTuBW1YOFc6o2N9jLGM
# 3ee8Jmje8o58CHK66QrVC2
# 0X8DcetL926BYiPJYstJTc
# 1dNIEtp7AY3oDAKCGg2XkH
# 0BF6mdNROWgYo3O3mNGrBc
# 5CtI0qwDJkDQGwXD1H1cLb
# 56lBX2WHqfGuoeZxZvUnVj
# 69bp2EbF7Q2rqc5N3ylezZ
# 2eMwDehkIC1j68U6FA3Eiq
# 1i1fxkWeaMmKEB4T7zqbzK
# 7ujx3NYtwO2LkmKGz59mXp
# 1AhDOtG9vPSOmsWgNW0BEY
# 2dpaYNEQHiRxtZbfNsse99
# 3U4isOIWM3VvDubwSI3y7a
# 7vfWgVGiLgnGbInU5lvSQg
# 7dt6x5M1jzdTEt8oCbisTK
# 2VxeLyX666F8uXCJ0dZF8B
# 4pdPtRcBmOSQDlJ3Fk945m
# 1brwdYwjltrJo7WHpIvbYt
# 3CRDbSIZ4r5MsZ0YwxuEkn
# 14msK75pk3pA33pzPVNtBF
# ...

# %%
len(song_id_list)
# Out:
# 100

# %% [markdown]
# # YYAAAAAASSSSSSSSSS!!!!!!!!!!!

# %% [markdown]
# # Time to get the FULL playlist data from my initial request

# %%
#artist_name = []
#track_name = []
#popularity = []
track_id = []
# test 200 at first, verify it works, put ^^^ in a diff cell so don't overwrite
endpoint = 'https://api.spotify.com/v1/playlists/0nwC4WbX0wGfH1Asj185R6/tracks'
for i in range(0,4200,100): #instead of range, track_id list
    print(i)
    playlist_full = requests.get(endpoint, headers=headers)
    #print(playlist_full.status_code)
    #print(playlist_full.url)
    playlist_full_json = playlist_full.json()
    #print(playlist_full_json.keys())
    for i, t in enumerate(playlist_full_json['items']):
        #artist_name.append(t['track'][0]['name'])
        #track_name.append(t['name'])
        track_id.append(t['track']['id'])
        #popularity.append(t['popularity'])
    endpoint = playlist_full_json['next']
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100

# %%
len(track_id)
# Out:
# 4152

# %%
print(track_id)
# Out:
# ['0FE9t6xYkqWXU2ahLh6D8X', '5ZULALImTm80tzUbYQYM9d', '7wGoVu4Dady5GV0Sv4UIsx', '1xznGGDReH1oQq0xzbwXa3', '7BKLCZ1jbUBVqRi2FVlTVw', '0sf12qNH5qcw8qpgymFOqD', '1A6OTy97kk0mMdm78rHsm8', '6T8cJz5lAqGer9GUHGyelE', '34gCuhDGsG4bRPIf9bb02f', '0TK2YIli7K1leLovkQiNik', '2TIlqbIneP0ZY1O0EzYLlc', '2Fxmhks0bxGSBdJ92vM42m', '5uCax9HTNlzGybIStD3vDh', '0tgVpDi06FyKpA1z0VMD4v', '6VRghJeP6I0w1KxkdWFfIh', '0ofbQMrRDsUaVKq2mGLEAb', '3hB5DgAiMAQ4DzYbsMq1IT', '1HNkqx9Ahdgi1Ixy2xkKkL', '7lQqaqZu0vjxzpdATOIsDt', '1Y8tTuBW1YOFc6o2N9jLGM', '3ee8Jmje8o58CHK66QrVC2', '0X8DcetL926BYiPJYstJTc', '1dNIEtp7AY3oDAKCGg2XkH', '0BF6mdNROWgYo3O3mNGrBc', '5CtI0qwDJkDQGwXD1H1cLb', '56lBX2WHqfGuoeZxZvUnVj', '69bp2EbF7Q2rqc5N3ylezZ', '2eMwDehkIC1j68U6FA3Eiq', '1i1fxkWeaMmKEB4T7zqbzK', '7ujx3NYtwO2LkmKGz59mXp', '1AhDOtG9vPSOmsWgNW0BEY', '2dpaYNEQHiRxtZbfNsse99', '3U4isOIWM3VvDubwSI3y7a', '7vfWgVGiLgnGbInU5lvSQg', '7dt6x5M1jzdTEt8oCbisTK', '2VxeLyX666F8uXCJ0dZF8B', '4pdPtRcBmOSQDlJ3Fk945m', '1brwdYwjltrJo7WHpIvbYt', '3CRDbSIZ
# ...

# %% [markdown]
# # Turn track_id into a .txt file

# %%
with open('track_id.txt', 'w') as outfile:
    outfile.write('\n'.join(track_id))

# %% [markdown]
# # open, read, save to variable

# %%
with open('track_id.txt', 'r') as track_ids:
    new_track_ids = track_ids.read()
    new_track_ids = new_track_ids.split('\n')

# %%
new_track_ids
# Out:
# ['0FE9t6xYkqWXU2ahLh6D8X',
#  '5ZULALImTm80tzUbYQYM9d',
#  '7wGoVu4Dady5GV0Sv4UIsx',
#  '1xznGGDReH1oQq0xzbwXa3',
#  '7BKLCZ1jbUBVqRi2FVlTVw',
#  '0sf12qNH5qcw8qpgymFOqD',
#  '1A6OTy97kk0mMdm78rHsm8',
#  '6T8cJz5lAqGer9GUHGyelE',
#  '34gCuhDGsG4bRPIf9bb02f',
#  '0TK2YIli7K1leLovkQiNik',
#  '2TIlqbIneP0ZY1O0EzYLlc',
#  '2Fxmhks0bxGSBdJ92vM42m',
#  '5uCax9HTNlzGybIStD3vDh',
#  '0tgVpDi06FyKpA1z0VMD4v',
#  '6VRghJeP6I0w1KxkdWFfIh',
#  '0ofbQMrRDsUaVKq2mGLEAb',
#  '3hB5DgAiMAQ4DzYbsMq1IT',
#  '1HNkqx9Ahdgi1Ixy2xkKkL',
#  '7lQqaqZu0vjxzpdATOIsDt',
#  '1Y8tTuBW1YOFc6o2N9jLGM',
#  '3ee8Jmje8o58CHK66QrVC2',
#  '0X8DcetL926BYiPJYstJTc',
#  '1dNIEtp7AY3oDAKCGg2XkH',
#  '0BF6mdNROWgYo3O3mNGrBc',
#  '5CtI0qwDJkDQGwXD1H1cLb',
#  '56lBX2WHqfGuoeZxZvUnVj',
#  '69bp2EbF7Q2rqc5N3ylezZ',
#  '2eMwDehkIC1j68U6FA3Eiq',
#  '1i1fxkWeaMmKEB4T7zqbzK',
#  '7ujx3NYtwO2LkmKGz59mXp',
#  '1AhDOtG9vPSOmsWgNW0BEY',
#  '2dpaYNEQHiRxtZbfNsse99',
#  '3U4isOIWM3VvDubwSI3y7a',
#  '7vfWgVGiLgnGbInU5lvSQg',
# ...

# %%
# Try this
artist = []
song_title = []
release_date =[]
track_id = []
# test 200 at first, verify it works, put ^^^ in a diff cell so don't overwrite
endpoint = 'https://api.spotify.com/v1/playlists/0nwC4WbX0wGfH1Asj185R6/tracks'
for i in range(0,200,100): #instead of range, track_id list
    print(i)
    playlist_full = requests.get(endpoint, headers=headers)
    
    print(playlist_full.status_code)
    print(playlist_full.url)
    
    playlist_full_json = playlist_full.json()
    print(playlist_full_json.keys())
    
    for i, t in enumerate(playlist_full_json['items'][0]['track']):
        #artist.append(t['artists']['name'])
        #song_title.append(t['name'])
        track_id.append(t['id'])
        release_date.append(t['release_date'])
    endpoint = playlist_full_json['next']
# Out:
# 0
# 200
# https://api.spotify.com/v1/playlists/0nwC4WbX0wGfH1Asj185R6/tracks
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-6778b970820b> in <module>
#      19         #artist.append(t['artists']['name'])
#      20         #song_title.append(t['name'])
# ---> 21         track_id.append(t['id'])
#      22         release_date.append(t['release_date'])
#      23     endpoint = playlist_full_json['next']
#
# TypeError: string indices must be integers

# %%
# 0FE9 = Shape of You
# 0nwC = playlist
